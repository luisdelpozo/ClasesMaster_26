# %% [markdown]
# # Visualization with Python II
#
#
#
# <img src="https://www.python.org/static/img/python-logo.png" alt="yogen" style="width: 200px; float: right;"/>
# <br>
# <br>
# <br>
# <img src="http://yogen.io/assets/logo.svg" alt="yogen" style="width: 200px; float: right;"/>

# %% [markdown]
# # Seaborn
#
# ![seaborn.PNG](data:image/png;base64,...)
#
#
# Seaborn is a statistical data visualization library. It's built on top of matplotlib and tries to "make a well-defined set of hard things easy" ([introduction to Seaborn](http://seaborn.pydata.org/introduction.html)).
#
# One advantage over matplotlib is that it works natively with DataFrame objects.
#
#
#
# https://www.datacamp.com/community/tutorials/seaborn-python-tutorial

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# https://en.wikipedia.org/wiki/Iris_flower_data_set
#
#
# https://github.com/allisonhorst/palmerpenguins

# %% [markdown]
# # matplotlib vs seaborn

# %%
np.random.seed(0)
npoints = 500
xs = np.linspace(0, 10, npoints)
ys = np.random.randn(npoints, 4).cumsum(axis=0)
ys.shape
plt.plot(xs, ys);

# %% [markdown]
# ### Line plots

# %%
df = pd.DataFrame(ys, index=xs, columns=list('abcd'))
sns.lineplot(data=df);

# %% [markdown]
# ### Scatter plots

# %%
from vega_datasets import data

data.list_datasets()
# Out:
# ['7zip',
#  'airports',
#  'annual-precip',
#  'anscombe',
#  'barley',
#  'birdstrikes',
#  'budget',
#  'budgets',
#  'burtin',
#  'cars',
#  'climate',
#  'co2-concentration',
#  'countries',
#  'crimea',
#  'disasters',
#  'driving',
#  'earthquakes',
#  'ffox',
#  'flare',
#  'flare-dependencies',
#  'flights-10k',
#  'flights-200k',
#  'flights-20k',
#  'flights-2k',
#  'flights-3m',
#  'flights-5k',
#  'flights-airport',
#  'gapminder',
#  'gapminder-health-income',
#  'gimp',
#  'github',
#  'graticule',
#  'income',
#  'iowa-electricity',
#  'iris',
#  'jobs',
#  'la-riots',
#  'londonBoroughs',
#  'londonCentroids',
#  'londonTubeLines',
#  'lookup_groups',
#  'lookup_people',
#  'miserables',
#  'monarchs',
#  'movies',
#  'normal-2d',
#  'obesity',
#  'ohlc',
#  'points',
#  'population',
#  'population_engineers_hurricanes',
#  'seattle-temps',
#  'seattle-weather',
#  'sf-temps',
#  'sp500',
#  'stocks',
#  'udistrict',
#  'unemployment',
#  'unemployment-across-industries',
#  'uniform-2d',
#  'us-10m',
#  'us-employment',
#  'us-state-capitals',
#  'volcano',
#  'weather',
#  'weball26',
#  'wheat',
#  'windvectors',
#  'world-110m',
#  'zipcodes']

# %%
monarchs = data.monarchs()
monarchs
# Out:
#           name  start   end  index  commonwealth
# 0    Elizabeth   1565  1603      0           NaN
# 1      James I   1603  1625      1           NaN
# 2    Charles I   1625  1649      2           NaN
# 3     Cromwell   1649  1660      3           1.0
# 4   Charles II   1660  1685      4           NaN
# 5     James II   1685  1689      5           NaN
# 6          W&M   1689  1702      6           NaN
# 7         Anne   1702  1714      7           NaN
# 8     George I   1714  1727      8           NaN
# 9    George II   1727  1760      9           NaN
# 10  George III   1760  1820     10           NaN
# 11   George IV   1820  1820     11           NaN

# %%
data.barley()
# Out:
#         yield           variety  year             site
# 0    27.00000         Manchuria  1931  University Farm
# 1    48.86667         Manchuria  1931           Waseca
# 2    27.43334         Manchuria  1931           Morris
# 3    39.93333         Manchuria  1931        Crookston
# 4    32.96667         Manchuria  1931     Grand Rapids
# ..        ...               ...   ...              ...
# 115  58.16667  Wisconsin No. 38  1932           Waseca
# 116  47.16667  Wisconsin No. 38  1932           Morris
# 117  35.90000  Wisconsin No. 38  1932        Crookston
# 118  20.66667  Wisconsin No. 38  1932     Grand Rapids
# 119  29.33333  Wisconsin No. 38  1932           Duluth
#
# [120 rows x 4 columns]

# %%
cars = data.cars()
cars.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration       Year Origin
# 0       130.0           3504          12.0 1970-01-01    USA
# 1       165.0           3693          11.5 1970-01-01    USA
# 2       150.0           3436          11.0 1970-01-01    USA
# 3       150.0           3433          12.0 1970-01-01    USA
# 4       140.0           3449          10.5 1970-01-01    USA

# %%
cars.dtypes
# Out:
# Name                        object
# Miles_per_Gallon           float64
# Cylinders                    int64
# Displacement               float64
# Horsepower                 float64
# Weight_in_lbs                int64
# Acceleration               float64
# Year                datetime64[ns]
# Origin                      object
# dtype: object

# %%
# !ls -l
# Out:
# total 18540
# -rw-rw-r-- 1 dsc dsc 2215908 ene 19 09:53 08_Visualizacion_I_LMdP.ipynb
# -rw-r--r-- 1 dsc dsc  422821 ene 18 19:06 08-visualization-I.empty.ipynb
# -rw-r--r-- 1 dsc dsc 1958277 ene 18 19:10 08-visualization-I.inclass.ipynb
# -rw-rw-r-- 1 dsc dsc 1509875 ene 16 14:06 08_Visualization_LMdP_1.ipynb
# -rw-rw-r-- 1 dsc dsc 4185712 ene 16 19:23 09_Visualization_2_LMdP.ipynb
# -rw-r--r-- 1 dsc dsc  445142 ene 15 13:20 09-visualization-II.empty.ipynb
# -rw-r--r-- 1 dsc dsc 3945935 ene 16 19:06 09-visualization-II.inclass.ipynb
# -rw-rw-r-- 1 dsc dsc 4052855 ene 19 14:10 09_Visualization_II_LMdP.ipynb
# -rw-rw-r-- 1 dsc dsc     752 ene 16 19:20 app.py
# -rw-rw-r-- 1 dsc dsc   26467 ene 16 19:05 cars.csv
# -rw-rw-r-- 1 dsc dsc   12452 ene 19 09:35 current_figure_2.pdf
# -rw-rw-r-- 1 dsc dsc   25348 ene 19 09:51 current_figure_2.png
# -rw-rw-r-- 1 dsc dsc   25608 ene 15 21:31 current_figure.png
# -rw-rw-r-- 1 dsc dsc    6009 ene 16 19:06 gapminder.csv
# -rw-rw-r-- 1 dsc dsc  116943 ene 16 12:38 visualization.svg

# %%
cars.to_csv('cars.csv')

# %%
sns.set_theme(style='darkgrid')

# %%
sns.__version__
# Out:
# '0.11.1'

# %%
sns.relplot(data=cars, x='Miles_per_Gallon', 
                       y='Displacement', 
                       hue='Origin')

# %%
sns.relplot(data=cars, x='Miles_per_Gallon', 
                       y='Displacement', 
                       hue='Weight_in_lbs')

# %%
sns.scatterplot(data=cars, x='Miles_per_Gallon', 
                       y='Displacement', 
                       hue='Weight_in_lbs');

# %%
sns.relplot(data=cars, x='Miles_per_Gallon', 
                       y='Displacement', 
                       kind='line')

# %%
sns.relplot(data=cars, x='Miles_per_Gallon', 
                       y='Displacement', 
                       kind='line',
                       hue='Origin')

# %% [markdown]
# # Joint

# %%
sns.jointplot(data=cars, x='Displacement', y='Weight_in_lbs')

# %%
sns.jointplot(data=cars, x='Displacement', 
                         y='Weight_in_lbs',
                         kind='kde')

# %% [markdown]
# # Joint Grid

# %%
grid = sns.JointGrid(data=cars, x='Displacement', y='Weight_in_lbs')

# %%
grid = sns.JointGrid(data=cars, x='Displacement', y='Weight_in_lbs')
grid.plot(sns.scatterplot, sns.distplot);
# Out:
# /home/dsc/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/dsc/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/dsc/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Histogram

# %%
sns.displot(data=cars, x='Miles_per_Gallon')

# %%
sns.histplot(data=cars, x='Miles_per_Gallon')
# Out:
# <AxesSubplot:xlabel='Miles_per_Gallon', ylabel='Count'>

# %% [markdown]
# By default, displot()/histplot() choose a default bin size based on the variance of the data and the number of observations.
#
# But you should not be over-reliant on such automatic approaches, because they depend on particular assumptions about the structure of your data. It is always advisable to check that your impressions of the distribution are consistent across different bin sizes

# %%
sns.displot(data=cars, x='Miles_per_Gallon', bins=25)

# %%
sns.displot(data=cars, x='Miles_per_Gallon', kind='kde', rug=True)

# %%
sns.displot(data=cars, x='Miles_per_Gallon', kind='kde', rug=True, hue='Origin')

# %% [markdown]
# stat{“count”, “frequency”, “density”, “probability”}
# Aggregate statistic to compute in each bin.
#
# **count** shows the number of observations
#
# **frequency** shows the number of observations divided by the bin width
#
# **density** normalizes counts so that the area of the histogram is 1
#
# probability normalizes counts so that the sum of the bar heights is 1

# %%
sns.displot(data=cars, x='Miles_per_Gallon',stat='density',hue='Origin')

# %%
sns.displot(data=cars, x='Miles_per_Gallon', kind='kde', rug=True,hue='Origin')

# %% [markdown]
# # Pairwise relationships

# %%
sns.pairplot(cars)

# %%
sns.relplot(data=cars, x='Miles_per_Gallon', y='Acceleration')

# %%
sns.pairplot(cars, hue='Origin', diag_kind='kde')

# %% [markdown]
# ### Linear relationships

# %%
sns.lmplot(data=cars, x='Horsepower', y='Weight_in_lbs')

# %%
sns.lmplot(data=cars, x='Horsepower', y='Weight_in_lbs', hue='Origin')

# %% [markdown]
# # Categorical Data
#
# https://seaborn.pydata.org/tutorial/categorical.html

# %% [markdown]
# #### swarm and strip plot
#
# https://github.com/allisonhorst/palmerpenguins

# %%
sns.stripplot(data=cars, x='Origin', y='Horsepower')
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %%
sns.swarmplot(data=cars, x='Origin', y='Horsepower')
# Out:
# /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %%
sns.swarmplot(data=cars, x='Origin', y='Horsepower', hue='Cylinders')
# Out:
# /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %%
sns.swarmplot(data=cars, y='Origin', x='Horsepower', hue='Cylinders')
# Out:
# /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 19.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 10.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Horsepower', ylabel='Origin'>

# %%
sns.relplot(data=cars, x='Year', y='Displacement', kind='line')

# %%
sns.relplot(data=cars, x='Year', y='Miles_per_Gallon', kind='line')

# %% [markdown]
# # Boxplot
# ![image.png](data:image/png;base64,...)

# %%
sns.boxplot(data=cars, x='Origin', y='Horsepower')
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %%
sns.boxenplot(data=cars, x='Origin', y='Horsepower')
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %%
sns.violinplot(data=cars, x='Origin', y='Horsepower')
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %% [markdown]
# ### Ejercicio
#
# ![violinplot.PNG](data:image/png;base64,...)

# %%
iris = data.iris()

# %%
sns.violinplot(data=iris, x='species', y='sepalLength')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepalLength'>

# %%
iris.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
species_order = ['virginica','versicolor','setosa']

# %%
sns.violinplot(data=iris, x='species', y='sepalLength',order=species_order)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepalLength'>

# %% [markdown]
# ### Barplot

# %%
sns.barplot(data=iris, x='species', y='sepalLength')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepalLength'>

# %%
sns.countplot(data=iris, x='species')
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %% [markdown]
# # Point plot
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.

# %%
sns.pointplot(data=cars, x='Cylinders', y='Horsepower', hue='Origin')
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='Horsepower'>

# %%
sns.pointplot(data=cars, x='Cylinders', y='Horsepower')
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='Horsepower'>

# %% [markdown]
# ### Heatmap

# %%
cars.corr()
# Out:
#                   Miles_per_Gallon  Cylinders  Displacement  Horsepower  \
# Miles_per_Gallon          1.000000  -0.775396     -0.804203   -0.778427
# Cylinders                -0.775396   1.000000      0.951787    0.844158
# Displacement             -0.804203   0.951787      1.000000    0.898326
# Horsepower               -0.778427   0.844158      0.898326    1.000000
# Weight_in_lbs            -0.831741   0.895220      0.932475    0.866586
# Acceleration              0.420289  -0.522452     -0.557984   -0.697124
#
#                   Weight_in_lbs  Acceleration
# Miles_per_Gallon      -0.831741      0.420289
# Cylinders              0.895220     -0.522452
# Displacement           0.932475     -0.557984
# Horsepower             0.866586     -0.697124
# Weight_in_lbs          1.000000     -0.430086
# Acceleration          -0.430086      1.000000

# %%
sns.heatmap(cars.corr(), cmap='RdBu', annot=True, center=0.0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # cluster map
#
# https://seaborn.pydata.org/generated/seaborn.clustermap.html#seaborn.clustermap

# %%
gapminder = data.gapminder_health_income()
gapminder
# Out:
#                 country  income  health  population
# 0           Afghanistan    1925   57.63    32526562
# 1               Albania   10620   76.00     2896679
# 2               Algeria   13434   76.50    39666519
# 3               Andorra   46577   84.10       70473
# 4                Angola    7615   61.00    25021974
# ..                  ...     ...     ...         ...
# 182             Vietnam    5623   76.50    93447601
# 183  West Bank and Gaza    4319   75.20     4668466
# 184               Yemen    3887   67.60    26832215
# 185              Zambia    4034   58.96    16211767
# 186            Zimbabwe    1801   60.01    15602751
#
# [187 rows x 4 columns]

# %%
gapminder.to_csv('gapminder.csv')

# %%
numerics = gapminder[['income', 'health', 'population']]

normalized =  numerics / numerics.max()
normalized
# Out:
#        income    health  population
# 0    0.014487  0.685256    0.023638
# 1    0.079924  0.903686    0.002105
# 2    0.101101  0.909631    0.028826
# 3    0.350527  1.000000    0.000051
# 4    0.057309  0.725327    0.018184
# ..        ...       ...         ...
# 182  0.042317  0.909631    0.067910
# 183  0.032504  0.894174    0.003393
# 184  0.029253  0.803805    0.019499
# 185  0.030359  0.701070    0.011781
# 186  0.013554  0.713555    0.011339
#
# [187 rows x 3 columns]

# %%
sns.heatmap(normalized)
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(normalized)

# %% [markdown]
# # Pandas
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
from pandas.plotting import parallel_coordinates

# %% [markdown]
# #### Parallel coordinates plot
# Parallel plot or Parallel Coordinates Plots allow to compare the feature of several individual observations on a set of numerical variables

# %%
f, ax = plt.subplots(1,1)

parallel_coordinates(iris, 'species', ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### autocorrelation plots
#
# Autocorrelation plots are often used for checking randomness in time series. This is done by computing autocorrelations for data values at varying time lags. If time series is random, such autocorrelations should be near zero for any and all time-lag separations. If time series is non-random then one or more of the autocorrelations will be significantly non-zero. The horizontal lines displayed in the plot correspond to 95% and 99% confidence bands.

# %%
from pandas.plotting import autocorrelation_plot

xs = np.linspace(0, 10)
ss = np.sin(xs)


autocorrelation_plot(ss)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
co2 = data.co2_concentration()

plt.plot(co2['Date'], co2['CO2'])

# %%
co2.iloc[:10]
# Out:
#          Date     CO2
# 0  1958-03-01  315.70
# 1  1958-04-01  317.46
# 2  1958-05-01  317.51
# 3  1958-07-01  315.86
# 4  1958-08-01  314.93
# 5  1958-09-01  313.21
# 6  1958-11-01  313.33
# 7  1958-12-01  314.67
# 8  1959-01-01  315.58
# 9  1959-02-01  316.48

# %%
co2.shape
# Out:
# (713, 2)

# %%
autocorrelation_plot(co2['CO2'])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
autocorrelation_plot(np.random.randn(1000))
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# # Altair Basics
#
# ![sss.PNG](data:image/png;base64,...)
#
# https://altair-viz.github.io/
#
# Altair is a declarative statistical visualization library for Python.
#
#  Altair's API is simple, friendly and consistent and built on top of the powerful Vega-Lite JSON specification. This elegant simplicity produces beautiful and effective visualizations with a minimal amount of code.
#
#
#  The key feature of this declarative approach is that the user is free to think about the data, rather than the mechanics of the visualization. Vega-Lite specifications are expressed in JavaScript Object Notation (JSON), a cross-platform format often used for storage of nested and/or hierarchical data. Altair builds a Python layer on top of this, so that rather than writing raw JSON strings the user can write declarative Python code.
#
#
#
#
#  **Altair provides a Python API for generating validated Vega-Lite specifications**

# %% [markdown]
#  ## What's the main difference with Matplotlib?
#
# Altair allows less customization and doesn't provide 3D visualization BUT :
#
# - It's Flexible
# - It's Interactive
# - It's intuitive and structured
# - It's based on Pandas not in numpy

# %%
# !pip install altair
# Out:
# Requirement already satisfied: altair in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (4.1.0)
# Requirement already satisfied: entrypoints in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from altair) (0.3)
# Requirement already satisfied: toolz in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from altair) (0.11.1)
# Requirement already satisfied: jsonschema in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from altair) (3.2.0)
# Requirement already satisfied: numpy in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from altair) (1.19.2)
# Requirement already satisfied: pandas>=0.18 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from altair) (1.2.0)
# Requirement already satisfied: jinja2 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from altair) (2.11.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from pandas>=0.18->altair) (2020.5)
# Requirement already satisfied: six>=1.5 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=0.18->altair) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from jsonschema->altair) (0.17.3)
# Requirement already satisfied: setuptools in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from jsonschema->altair) (51.1.2.post20210112)
# Requirement already satisfied: attrs>=17.4.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from jsonschema->altair) (20.3.0)

# %%
import altair as alt

alt.__version__
# Out:
# '4.1.0'

# %% [markdown]
# ## Example Matplotlib vs Altair

# %%
xs = np.linspace(0, 10)
ys = 3 * xs ** 2

plt.plot(xs, ys)

# %%
alt_df = pd.DataFrame({'X' : xs, 'Y' : ys})
alt_df.head()
# Out:
#           X         Y
# 0  0.000000  0.000000
# 1  0.204082  0.124948
# 2  0.408163  0.499792
# 3  0.612245  1.124531
# 4  0.816327  1.999167

# %%
alt.Chart(alt_df).mark_line().encode(x='X', y='Y')
# Out:
# alt.Chart(...)

# %% [markdown]
# # Example
#
# Let's build a very simple example with a simple made up dataset

# %%
cars_chart = alt.Chart(cars)

cars_chart.mark_point()
# Out:
# alt.Chart(...)

# %% [markdown]
# We have just defined the chart but have not tell the chart do anything with the data.
# We have to use the mark attribute of the chart object to specify how we want to visualize it
#
# `alt.Chart(data).mark_*`

# %% [markdown]
# Altair automatically recognizes the data type in the dataframe

# %%
cars_chart.mark_point().encode(x='Miles_per_Gallon', 
                               y='Displacement')
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_line().encode(x='Miles_per_Gallon', 
                               y='Displacement')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Example taking data from JSON

# %%
data.movies.url
# Out:
# 'https://cdn.jsdelivr.net/npm/vega-datasets@v1.29.0/data/movies.json'

# %%
import requests

response = requests.get(data.movies.url)
movie_data = response.json()

# %%
movie_data[0]
# Out:
# {'Title': 'The Land Girls',
#  'US_Gross': 146083,
#  'Worldwide_Gross': 146083,
#  'US_DVD_Sales': None,
#  'Production_Budget': 8000000,
#  'Release_Date': 'Jun 12 1998',
#  'MPAA_Rating': 'R',
#  'Running_Time_min': None,
#  'Distributor': 'Gramercy',
#  'Source': None,
#  'Major_Genre': None,
#  'Creative_Type': None,
#  'Director': None,
#  'Rotten_Tomatoes_Rating': None,
#  'IMDB_Rating': 6.1,
#  'IMDB_Votes': 1071}

# %%
data.movies.url
# Out:
# 'https://cdn.jsdelivr.net/npm/vega-datasets@v1.29.0/data/movies.json'

# %%
movie_chart = alt.Chart(data.movies.url)
movie_chart.mark_point().encode(alt.X('Production_Budget', type='quantitative'),
                                alt.Y('IMDB_Rating', type='quantitative'))
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Example 2

# %%
movie_chart.mark_bar().encode(alt.X('Production_Budget', 
                                    bin=alt.Bin(extent=[0,3e8], step=1e7), 
                                    type='quantitative'),
                              y='count()')
# Out:
# alt.Chart(...)

# %%
movie_chart.mark_bar().encode(alt.X('Production_Budget', 
                                    bin=alt.Bin(extent=[0,3e8], step=1e7), 
                                    type='quantitative'),
                              alt.Y(aggregate='count', type='quantitative'))
# Out:
# alt.Chart(...)

# %% [markdown]
# https://altair-viz.github.io/user_guide/generated/toplevel/altair.Chart.html#altair.Chart

# %% [markdown]
# It can be especified using `alt.X`  instead.
#
# The type must also be specified:
# ['quantitative', 'ordinal', 'temporal', 'nominal']

# %% [markdown]
# https://altair-viz.github.io/user_guide/encoding.html#shorthand-description
#
#
# ![shorthand.PNG](data:image/png;base64,...)

# %%
cars_chart.mark_point().encode(x='Origin:N',
                               y='Displacement:Q')
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_point().encode(x='Origin:N',
                               y='mean(Displacement):Q')
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_bar().encode(x='Origin:N',
                             y='mean(Displacement):Q')
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_bar().encode(x='Origin:N',
                             y='mean(Displacement):Q',
                             color='Cylinders:N'   )
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_point().encode(x='Miles_per_Gallon',
                               y='Weight_in_lbs', 
                               color='Origin').interactive()
# Out:
# alt.Chart(...)

# %%
cars.columns
# Out:
# Index(['Name', 'Miles_per_Gallon', 'Cylinders', 'Displacement', 'Horsepower',
#        'Weight_in_lbs', 'Acceleration', 'Year', 'Origin'],
#       dtype='object')

# %%
cars_chart.mark_point().encode(x='Miles_per_Gallon',
                               y='Weight_in_lbs', 
                               color='Origin',
                               tooltip='Name').interactive()
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_point().encode(x='Miles_per_Gallon',
                               y='Weight_in_lbs', 
                               color='Origin',
                               tooltip='Name').add_selection(alt.selection_interval())
# Out:
# alt.Chart(...)

# %%
interval = alt.selection_interval()

cars_chart.mark_point().encode(x='Miles_per_Gallon',
                               y='Weight_in_lbs', 
                               color=alt.condition(interval, 'Origin', alt.value('lightgrey')),
                               tooltip='Name').add_selection(interval)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Streamlit

# %% [markdown]
# Streamlit is a new library that allow to transform simple python code to web apps easily
#
# https://www.streamlit.io/
#
# https://docs.streamlit.io/en/stable/getting_started.html
#
# https://docs.streamlit.io/en/stable/api.html

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (0.74.1)
# Requirement already satisfied: pydeck>=0.1.dev5 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (0.5.0)
# Requirement already satisfied: base58 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (2.1.0)
# Requirement already satisfied: blinker in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (1.4)
# Requirement already satisfied: watchdog in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (1.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (8.1.0)
# Requirement already satisfied: tzlocal in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (2.1)
# Requirement already satisfied: tornado>=5.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (6.1)
# Requirement already satisfied: validators in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: astor in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (0.8.1)
# Requirement already satisfied: gitpython in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (3.1.12)
# Requirement already satisfied: click>=7.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (7.1.2)
# Requirement already satisfied: altair>=3.2.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (4.1.0)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (3.13.0)
# Requirement already satisfied: requests in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (2.25.1)
# Requirement already satisfied: pandas>=0.21.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (1.2.0)
# Requirement already satisfied: python-dateutil in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (2.8.1)
# Requirement already satisfied: numpy in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (1.19.2)
# Requirement already satisfied: toml in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: packaging in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (20.8)
# Requirement already satisfied: cachetools>=4.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from streamlit) (4.1.1)
# Requirement already satisfied: jsonschema in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: toolz in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: entrypoints in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: jinja2 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (2.11.2)
# Requirement already satisfied: pytz>=2017.3 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from pandas>=0.21.0->streamlit) (2020.5)
# Requirement already satisfied: six>=1.9 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from protobuf!=3.11,>=3.6.0->streamlit) (1.15.0)
# Requirement already satisfied: setuptools in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from protobuf!=3.11,>=3.6.0->streamlit) (51.1.2.post20210112)
# Requirement already satisfied: traitlets>=4.3.2 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: ipykernel>=5.1.2 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.3)
# Requirement already satisfied: jupyter-client in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (6.1.7)
# Requirement already satisfied: ipython>=5.0.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.19.0)
# Requirement already satisfied: backcall in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: pygments in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.7.4)
# Requirement already satisfied: pickleshare in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: decorator in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.8)
# Requirement already satisfied: jedi>=0.10 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.17.2)
# Requirement already satisfied: nbformat>=4.2.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: jupyter-core in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.7.0)
# Requirement already satisfied: ipython-genutils in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from jsonschema->altair>=3.2.0->streamlit) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from jsonschema->altair>=3.2.0->streamlit) (20.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: wcwidth in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.1.6)
# Requirement already satisfied: Send2Trash in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: nbconvert in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.7)
# Requirement already satisfied: argon2-cffi in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.1.0)
# Requirement already satisfied: prometheus-client in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.0)
# Requirement already satisfied: pyzmq>=17 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.0.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.2)
# Requirement already satisfied: cffi>=1.0.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.4)
# Requirement already satisfied: pycparser in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from gitpython->streamlit) (4.0.5)
# Requirement already satisfied: smmap<4,>=3.0.1 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython->streamlit) (3.0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: defusedxml in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: bleach in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.2.1)
# Requirement already satisfied: jupyterlab-pygments in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: testpath in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: nest-asyncio in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: async-generator in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.10)
# Requirement already satisfied: webencodings in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from requests->streamlit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from requests->streamlit) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from requests->streamlit) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/dani/anaconda3/envs/master2021/lib/python3.9/site-packages (from requests->streamlit) (1.26.2)

# %%
import streamlit as st

st.__version__
# Out:
# '0.74.1'

# %%
st.write('holi')

# %% [markdown]
# ### The writefile cell magic
#
# This is a way to keep everything inside the notebook, but it's not the ideal way to code a .py file.

# %%
# %%writefile app.py

hola que tal

mi lista para los reyes mages es...
# Out:
# Writing app.py

# %%
# %%writefile app.py

import streamlit as st
from vega_datasets import data
import altair as alt

cars = data.cars()

'# Bienvenidos a mi app'

my_chart = alt.Chart(cars).mark_point().encode(x='Displacement', 
                                    y='Horsepower')
st.altair_chart(my_chart)
# Out:
# Overwriting app.py

# %%
alt.Chart(cars).mark_point().encode(x='Displacement', 
                                    y='Horsepower')
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Interactividad

# %%
# %%writefile app.py

import streamlit as st
from vega_datasets import data
import altair as alt
import time

st.write('# Bienvenidos a mi app')


name = st.text_input('Como te llamas, guapi?')
country = st.selectbox('De qué pais quieres ver datos?', ['USA', 'Europe', 'Japan'])


cars = data.cars()
subset = cars[cars['Origin']== country]


my_chart = alt.Chart(subset).mark_point().encode(x='Displacement', 
                                    y='Horsepower')
st.altair_chart(my_chart)

st.write('gracias por visitarme, %s' % name)
# Out:
# Overwriting app.py

# %% [markdown]
# ### Cacheo

# %%
# %%writefile app.py

import streamlit as st
from vega_datasets import data
import altair as alt
import time

st.write('# Bienvenidos a mi app')

@st.cache
def get_cars():
    time.sleep(3)
    return data.cars()

@st.cache
def get_subset(origin, df):
    time.sleep(5)
    return df[df['Origin']== origin]


name = st.text_input('Como te llamas, guapi?')
country = st.selectbox('De qué pais quieres ver datos?', ['USA', 'Europe', 'Japan'])


cars = get_cars()
subset = get_subset(country, cars)


my_chart = alt.Chart(subset).mark_point().encode(x='Displacement', 
                                    y='Horsepower')
st.altair_chart(my_chart)

st.write('gracias por visitarme, %s' % name)
# Out:
# Overwriting app.py

# %%
cars['Origin'].unique()
# Out:
# array(['USA', 'Europe', 'Japan'], dtype=object)

# %% [markdown]
# # Bokeh
#
# Bokeh "is a Python interactive visualization library that targets
# modern web browsers for presentation".
#
# Two components: A Python backend and a JS frontend.
#
# The way we use it is to declare our graphs in Python.
#
# The Python objects will in turn generate a series of JSON objects that describe a _scenegraph_. The JS component will generate the actual visualization from that scenegraph. The upside of this is that we don't need to work with JS, but our visualizations will be browser-based and interactive
#
# https://bokeh.pydata.org/en/latest/docs/gallery.html
#
# https://bokeh.pydata.org/en/latest/

# %% [markdown]
# # Plotly
#
# https://www.analyticsvidhya.com/blog/2017/01/beginners-guide-to-create-beautiful-interactive-data-visualizations-using-plotly-in-r-and-python/
#
# Plotly is a multi-language tool for creating interactive visualizations. It's built on top  of D3.

# %% [markdown]
# ## Dash
#
# "Shiny for Python"

# %% [markdown]
# # Additional references
#
# [Matplotlib documentation](http://matplotlib.org/contents.html)
#
# [The matplotlib FAQ](http://matplotlib.org/faq/usage_faq.html)
#
# [Matplotlib cheat sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf)
#
# [Nicolas P. Rougier's matplotlib tutorial](http://www.labri.fr/perso/nrougier/teaching/matplotlib/)
#
# [Anatomy of Matplotlib](https://github.com/matplotlib/AnatomyOfMatplotlib)
#
# [$\LaTeX$](https://www.latex-project.org/)
#
# [Python graph gallery](https://python-graph-gallery.com/)
#
# [Effective matplotlib](https://pbpython.com/effective-matplotlib.html)
#
# [Python Data Science Handbook](https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/Index.ipynb)
#
# [more plots](https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/)
#
# https://www.datacamp.com/community/tutorials/seaborn-python-tutorial
#
#
# [Bokeh User Guide](http://bokeh.pydata.org/en/latest/docs/user_guide.html)
#
# [Bokeh Tutorials](http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/index.ipynb)
#
# [Dash](https://plot.ly/dash/)
#
# [Dash being spotted before release](https://www.reddit.com/r/Python/comments/6imhxa/plotly_has_just_released_dash_20_a_shinylike_tool/)
#
# [Facets](https://pair-code.github.io/facets/)
#
# [Facets release Google research blog entry](https://research.googleblog.com/2017/07/facets-open-source-visualization-tool.html)
#
# [A great Altair tutorial](https://github.com/altair-viz/altair-tutorial)
