# %% [markdown]
# # Visualization with Python II
#
#
#
# <img src="https://www.python.org/static/img/python-logo.png" alt="yogen" style="width: 200px; float: right;"/>
# <br>
# <br>
# <br>
# <img src="http://yogen.io/assets/logo.svg" alt="yogen" style="width: 200px; float: right;"/>

# %% [markdown]
# # Seaborn
#
# ![seaborn.PNG](data:image/png;base64,...)
#
#
# Seaborn is a statistical data visualization library. It's built on top of matplotlib and tries to "make a well-defined set of hard things easy" ([introduction to Seaborn](http://seaborn.pydata.org/introduction.html)).
#
# One advantage over matplotlib is that it works natively with DataFrame objects.
#
#
#
# https://www.datacamp.com/community/tutorials/seaborn-python-tutorial

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# https://en.wikipedia.org/wiki/Iris_flower_data_set
#
#
# https://github.com/allisonhorst/palmerpenguins

# %% [markdown]
# # matplotlib vs seaborn

# %%
npoints = 500
xs = np.linspace(0, 10, npoints)
ys = np.random.randn(npoints, 4).cumsum(axis=0)
ys.shape
plt.plot(xs, ys);

# %%
df = pd.DataFrame(ys, index=xs, columns=list('abcd'))
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Scatter plots

# %%
# !pip install vega_datasets
# Out:
# Collecting vega_datasets
#   Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 10.1 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /home/dsc/anaconda3/lib/python3.8/site-packages (from vega_datasets) (1.1.3)
# Requirement already satisfied: numpy>=1.15.4 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pandas->vega_datasets) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pandas->vega_datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pandas->vega_datasets) (2020.1)
# Requirement already satisfied: six>=1.5 in /home/dsc/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->vega_datasets) (1.15.0)
# Installing collected packages: vega-datasets
# Successfully installed vega-datasets-0.9.0

# %%
#Librería con mogollón de datasets
from vega_datasets import data

# %%
data.list_datasets()
# Out:
# ['7zip',
#  'airports',
#  'annual-precip',
#  'anscombe',
#  'barley',
#  'birdstrikes',
#  'budget',
#  'budgets',
#  'burtin',
#  'cars',
#  'climate',
#  'co2-concentration',
#  'countries',
#  'crimea',
#  'disasters',
#  'driving',
#  'earthquakes',
#  'ffox',
#  'flare',
#  'flare-dependencies',
#  'flights-10k',
#  'flights-200k',
#  'flights-20k',
#  'flights-2k',
#  'flights-3m',
#  'flights-5k',
#  'flights-airport',
#  'gapminder',
#  'gapminder-health-income',
#  'gimp',
#  'github',
#  'graticule',
#  'income',
#  'iowa-electricity',
#  'iris',
#  'jobs',
#  'la-riots',
#  'londonBoroughs',
#  'londonCentroids',
#  'londonTubeLines',
#  'lookup_groups',
#  'lookup_people',
#  'miserables',
#  'monarchs',
#  'movies',
#  'normal-2d',
#  'obesity',
#  'ohlc',
#  'points',
#  'population',
#  'population_engineers_hurricanes',
#  'seattle-temps',
#  'seattle-weather',
#  'sf-temps',
#  'sp500',
#  'stocks',
#  'udistrict',
#  'unemployment',
#  'unemployment-across-industries',
#  'uniform-2d',
#  'us-10m',
#  'us-employment',
#  'us-state-capitals',
#  'volcano',
#  'weather',
#  'weball26',
#  'wheat',
#  'windvectors',
#  'world-110m',
#  'zipcodes']

# %%
monarchs = data.monarchs()
monarchs
# Out:
#           name  start   end  index  commonwealth
# 0    Elizabeth   1565  1603      0           NaN
# 1      James I   1603  1625      1           NaN
# 2    Charles I   1625  1649      2           NaN
# 3     Cromwell   1649  1660      3           1.0
# 4   Charles II   1660  1685      4           NaN
# 5     James II   1685  1689      5           NaN
# 6          W&M   1689  1702      6           NaN
# 7         Anne   1702  1714      7           NaN
# 8     George I   1714  1727      8           NaN
# 9    George II   1727  1760      9           NaN
# 10  George III   1760  1820     10           NaN
# 11   George IV   1820  1820     11           NaN

# %%
data.barley()
# Out:
#         yield           variety  year             site
# 0    27.00000         Manchuria  1931  University Farm
# 1    48.86667         Manchuria  1931           Waseca
# 2    27.43334         Manchuria  1931           Morris
# 3    39.93333         Manchuria  1931        Crookston
# 4    32.96667         Manchuria  1931     Grand Rapids
# ..        ...               ...   ...              ...
# 115  58.16667  Wisconsin No. 38  1932           Waseca
# 116  47.16667  Wisconsin No. 38  1932           Morris
# 117  35.90000  Wisconsin No. 38  1932        Crookston
# 118  20.66667  Wisconsin No. 38  1932     Grand Rapids
# 119  29.33333  Wisconsin No. 38  1932           Duluth
#
# [120 rows x 4 columns]

# %%
data.cars()
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 0         130.0           3504          12.0 1970-01-01     USA
# 1         165.0           3693          11.5 1970-01-01     USA
# 2         150.0           3436          11.0 1970-01-01     USA
# 3         150.0           3433          12.0 1970-01-01     USA
# 4         140.0           3449          10.5 1970-01-01     USA
# ..          ...            ...           ...        ...     ...
# 401        86.0           2790          15.6 1982-01-01     USA
# 402        52.0           2130          24.6 1982-01-01  Europe
# 403        84.0           2295          11.6 1982-01-01     USA
# 404        79.0           2625          18.6 1982-01-01     USA
# 405        82.0           2720          19.4 1982-01-01     USA
#
# [406 rows x 9 columns]

# %%
cars = data.cars()
cars.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration       Year Origin
# 0       130.0           3504          12.0 1970-01-01    USA
# 1       165.0           3693          11.5 1970-01-01    USA
# 2       150.0           3436          11.0 1970-01-01    USA
# 3       150.0           3433          12.0 1970-01-01    USA
# 4       140.0           3449          10.5 1970-01-01    USA

# %%
sns.set_theme(style='darkgrid')

# %%
sns.relplot(data=cars, x='Miles_per_Gallon', y='Displacement')

# %%
#hue --> Categorical variables
sns.relplot(data=cars, x='Miles_per_Gallon', 
            y='Displacement',
            hue='Origin')

# %%
sns.relplot(data=cars, x='Miles_per_Gallon', 
            y='Displacement',
            hue='Weight_in_lbs')

# %%
sns.__version__
# Out:
# '0.11.0'

# %%
sns.relplot(data=cars, x='Miles_per_Gallon', 
            y='Displacement', kind='line')

# %% [markdown]
# # Joint

# %%
sns.jointplot(data=cars, x='Displacement', y = 'Weight_in_lbs')

# %%
sns.jointplot(data=cars, x='Displacement', 
            y = 'Weight_in_lbs',
            kind='kde')

# %% [markdown]
# # Joint Grid

# %%
sns.JointGrid(data=cars, x='Displacement', 
            y = 'Weight_in_lbs')

# %%
grid = sns.JointGrid(data=cars, x='Displacement', 
            y = 'Weight_in_lbs')

# %%
grid = sns.JointGrid(data=cars, x='Displacement', y = 'Weight_in_lbs')
grid.plot(sns.scatterplot, sns.histplot)

# %% [markdown]
# # Histogram

# %%
# !pip install --upgrade seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
#      |████████████████████████████████| 285 kB 10.5 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: scipy>=1.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from seaborn) (1.5.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /home/dsc/anaconda3/lib/python3.8/site-packages (from seaborn) (1.19.2)
# Requirement already satisfied, skipping upgrade: pandas>=0.23 in /home/dsc/anaconda3/lib/python3.8/site-packages (from seaborn) (1.1.3)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from seaborn) (3.3.2)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2.8.1)
# Requirement already satisfied, skipping upgrade: certifi>=2020.06.20 in /home/dsc/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2020.6.20)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/dsc/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (8.0.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/dsc/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in /home/dsc/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/dsc/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->seaborn) (1.15.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.0
#     Uninstalling seaborn-0.11.0:
#       Successfully uninstalled seaborn-0.11.0
# Successfully installed seaborn-0.11.1

# %%
from importlib import reload
reload(sns)
sns.__version__
# Out:
# '0.11.1'

# %%
sns.displot(data=cars, x='Miles_per_Gallon')

# %%
sns.displot(data=cars, x='Miles_per_Gallon',bins=25)

# %%
sns.displot(data=cars, x='Miles_per_Gallon',kind='kde')

# %%
sns.displot(data=cars, x='Miles_per_Gallon',kind='kde',rug=True)

# %%
sns.displot(data=cars, x='Miles_per_Gallon',kind='kde',rug=True,
           hue='Origin')

# %% [markdown]
# By default, displot()/histplot() choose a default bin size based on the variance of the data and the number of observations.
#
# But you should not be over-reliant on such automatic approaches, because they depend on particular assumptions about the structure of your data. It is always advisable to check that your impressions of the distribution are consistent across different bin sizes

# %% [markdown]
# stat{“count”, “frequency”, “density”, “probability”}
# Aggregate statistic to compute in each bin.
#
# **count** shows the number of observations
#
# **frequency** shows the number of observations divided by the bin width
#
# **density** normalizes counts so that the area of the histogram is 1
#
# probability normalizes counts so that the sum of the bar heights is 1

# %% [markdown]
# # Pairwise relationships

# %%
sns.pairplot(cars)

# %%
sns.relplot(data=cars, x='Miles_per_Gallon', y='Acceleration')

# %%
sns.pairplot(cars, hue='Origin', diag_kind='kde')

# %% [markdown]
# ### Linear relationships

# %%
sns.lmplot(data=cars, x='Horsepower', y='Weight_in_lbs')
#No te da los parámetros de la linea de regresión

# %%
sns.lmplot(data=cars, x='Horsepower', y='Weight_in_lbs',hue='Origin')

# %% [markdown]
# # Categorical Data
#
# https://seaborn.pydata.org/tutorial/categorical.html

# %% [markdown]
# #### swarm and strip plot
#
# https://github.com/allisonhorst/palmerpenguins

# %%
sns.stripplot(data=cars, x='Origin',y='Horsepower')
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %%
sns.swarmplot(data=cars, x='Origin',y='Horsepower')
#Igual que el anterior pero sin solape
# Out:
# /home/dsc/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %%
sns.swarmplot(data=cars, x='Origin',y='Horsepower',hue='Cylinders')
# Out:
# /home/dsc/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %%
sns.swarmplot(data=cars, y='Origin',x='Horsepower',hue='Cylinders')
# Out:
# /home/dsc/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 19.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/dsc/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 10.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Horsepower', ylabel='Origin'>

# %%
cars.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration       Year Origin
# 0       130.0           3504          12.0 1970-01-01    USA
# 1       165.0           3693          11.5 1970-01-01    USA
# 2       150.0           3436          11.0 1970-01-01    USA
# 3       150.0           3433          12.0 1970-01-01    USA
# 4       140.0           3449          10.5 1970-01-01    USA

# %%
cars.Year
# Out:
# 0     1970-01-01
# 1     1970-01-01
# 2     1970-01-01
# 3     1970-01-01
# 4     1970-01-01
#          ...
# 401   1982-01-01
# 402   1982-01-01
# 403   1982-01-01
# 404   1982-01-01
# 405   1982-01-01
# Name: Year, Length: 406, dtype: datetime64[ns]

# %%
sns.relplot(data=cars, x= 'Year',y='Displacement',
            hue='Origin', kind='line')

# %%
sns.relplot(data=cars, x= 'Year',y='Miles_per_Gallon',
            hue='Origin', kind='line')

# %% [markdown]
# # Boxplot
# ![image.png](data:image/png;base64,...)

# %%
sns.boxplot(data=cars, x='Origin', y='Horsepower')
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %%
sns.boxenplot(data=cars, x='Origin', y='Horsepower')
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %%
sns.violinplot(data=cars, x='Origin', y='Horsepower')
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %% [markdown]
# ### Ejercicio
#
# ![violinplot.PNG](data:image/png;base64,...)

# %%
iris = data.iris()
iris.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
iris_index = iris.species.value_counts().index
iris_list = iris_index.tolist()
iris_list
# Out:
# ['versicolor', 'virginica', 'setosa']

# %%
sns.violinplot(data=iris, y='sepalLength', x='species')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepalLength'>

# %% [markdown]
# Order by decreasing median

# %% [markdown]
# ### Barplot

# %%
sns.barplot(data=iris, x='species', y='sepalLength')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepalLength'>

# %%
sns.countplot(data=iris, x='species')
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %% [markdown]
# # Point plot
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.

# %%
sns.pointplot(data=cars, x='Origin', y='Horsepower')
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='Horsepower'>

# %%
sns.pointplot(data=cars, x='Cylinders', y='Horsepower',hue='Origin')
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='Horsepower'>

# %% [markdown]
# ### Heatmap

# %%
cars.corr()
# Out:
#                   Miles_per_Gallon  Cylinders  Displacement  Horsepower  \
# Miles_per_Gallon          1.000000  -0.775396     -0.804203   -0.778427
# Cylinders                -0.775396   1.000000      0.951787    0.844158
# Displacement             -0.804203   0.951787      1.000000    0.898326
# Horsepower               -0.778427   0.844158      0.898326    1.000000
# Weight_in_lbs            -0.831741   0.895220      0.932475    0.866586
# Acceleration              0.420289  -0.522452     -0.557984   -0.697124
#
#                   Weight_in_lbs  Acceleration
# Miles_per_Gallon      -0.831741      0.420289
# Cylinders              0.895220     -0.522452
# Displacement           0.932475     -0.557984
# Horsepower             0.866586     -0.697124
# Weight_in_lbs          1.000000     -0.430086
# Acceleration          -0.430086      1.000000

# %%
sns.heatmap(cars.corr(),cmap='hot')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(),cmap='RdBu',center=0.0)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(),cmap='RdBu',center=0.0, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # cluster map
#
# https://seaborn.pydata.org/generated/seaborn.clustermap.html#seaborn.clustermap

# %%
gapminder = data.gapminder_health_income()
gapminder.head()
# Out:
#        country  income  health  population
# 0  Afghanistan    1925   57.63    32526562
# 1      Albania   10620   76.00     2896679
# 2      Algeria   13434   76.50    39666519
# 3      Andorra   46577   84.10       70473
# 4       Angola    7615   61.00    25021974

# %%
sns.heatmap(data=gapminder[['income','health','population']])
# Out:
# <AxesSubplot:>

# %%
numerics = gapminder[['income','health','population']]

normalized = numerics/numerics.max()
normalized
# Out:
#        income    health  population
# 0    0.014487  0.685256    0.023638
# 1    0.079924  0.903686    0.002105
# 2    0.101101  0.909631    0.028826
# 3    0.350527  1.000000    0.000051
# 4    0.057309  0.725327    0.018184
# ..        ...       ...         ...
# 182  0.042317  0.909631    0.067910
# 183  0.032504  0.894174    0.003393
# 184  0.029253  0.803805    0.019499
# 185  0.030359  0.701070    0.011781
# 186  0.013554  0.713555    0.011339
#
# [187 rows x 3 columns]

# %%
sns.heatmap(normalized)
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(normalized)

# %% [markdown]
# # Pandas
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
from pandas.plotting import parallel_coordinates

# %% [markdown]
# #### Parallel coordinates plot
# Parallel plot or Parallel Coordinates Plots allow to compare the feature of several individual observations on a set of numerical variables

# %%
f, ax = plt.subplots(1,1)
parallel_coordinates(iris, 'species', ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### autocorrelation plots
#
# Autocorrelation plots are often used for checking randomness in time series. This is done by computing autocorrelations for data values at varying time lags. If time series is random, such autocorrelations should be near zero for any and all time-lag separations. If time series is non-random then one or more of the autocorrelations will be significantly non-zero. The horizontal lines displayed in the plot correspond to 95% and 99% confidence bands.

# %%
from pandas.plotting import autocorrelation_plot

# %%
xs = np.linspace(0,10)
ss = np.sin(xs)

# %%
autocorrelation_plot(ss)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
data.list_datasets()
# Out:
# ['7zip',
#  'airports',
#  'annual-precip',
#  'anscombe',
#  'barley',
#  'birdstrikes',
#  'budget',
#  'budgets',
#  'burtin',
#  'cars',
#  'climate',
#  'co2-concentration',
#  'countries',
#  'crimea',
#  'disasters',
#  'driving',
#  'earthquakes',
#  'ffox',
#  'flare',
#  'flare-dependencies',
#  'flights-10k',
#  'flights-200k',
#  'flights-20k',
#  'flights-2k',
#  'flights-3m',
#  'flights-5k',
#  'flights-airport',
#  'gapminder',
#  'gapminder-health-income',
#  'gimp',
#  'github',
#  'graticule',
#  'income',
#  'iowa-electricity',
#  'iris',
#  'jobs',
#  'la-riots',
#  'londonBoroughs',
#  'londonCentroids',
#  'londonTubeLines',
#  'lookup_groups',
#  'lookup_people',
#  'miserables',
#  'monarchs',
#  'movies',
#  'normal-2d',
#  'obesity',
#  'ohlc',
#  'points',
#  'population',
#  'population_engineers_hurricanes',
#  'seattle-temps',
#  'seattle-weather',
#  'sf-temps',
#  'sp500',
#  'stocks',
#  'udistrict',
#  'unemployment',
#  'unemployment-across-industries',
#  'uniform-2d',
#  'us-10m',
#  'us-employment',
#  'us-state-capitals',
#  'volcano',
#  'weather',
#  'weball26',
#  'wheat',
#  'windvectors',
#  'world-110m',
#  'zipcodes']

# %%
co2 = data.co2_concentration()

# %%
co2.dtypes
# Out:
# Date     object
# CO2     float64
# dtype: object

# %%
plt.plot(co2['Date'],co2['CO2'])

# %%
co2.iloc[:10]
# Out:
#          Date     CO2
# 0  1958-03-01  315.70
# 1  1958-04-01  317.46
# 2  1958-05-01  317.51
# 3  1958-07-01  315.86
# 4  1958-08-01  314.93
# 5  1958-09-01  313.21
# 6  1958-11-01  313.33
# 7  1958-12-01  314.67
# 8  1959-01-01  315.58
# 9  1959-02-01  316.48

# %%
co2.shape
# Out:
# (713, 2)

# %%
autocorrelation_plot(co2['CO2'])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
autocorrelation_plot(np.random.randn(1000))
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# # Altair Basics
#
# ![sss.PNG](data:image/png;base64,...)
#
# https://altair-viz.github.io/
#
# Altair is a declarative statistical visualization library for Python.
#
#  Altair's API is simple, friendly and consistent and built on top of the powerful Vega-Lite JSON specification. This elegant simplicity produces beautiful and effective visualizations with a minimal amount of code.
#
#
#  The key feature of this declarative approach is that the user is free to think about the data, rather than the mechanics of the visualization. Vega-Lite specifications are expressed in JavaScript Object Notation (JSON), a cross-platform format often used for storage of nested and/or hierarchical data. Altair builds a Python layer on top of this, so that rather than writing raw JSON strings the user can write declarative Python code.
#
#
#
#
#  **Altair provides a Python API for generating validated Vega-Lite specifications**

# %% [markdown]
#  ## What's the main difference with Matplotlib?
#
# Altair allows less customization and doesn't provide 3D visualization BUT :
#
# - It's Flexible
# - It's Interactive
# - It's intuitive and structured
# - It's based on Pandas not in numpy

# %%
# !pip install altair
# Out:
# Collecting altair
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
#      |████████████████████████████████| 727 kB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: entrypoints in /home/dsc/anaconda3/lib/python3.8/site-packages (from altair) (0.3)
# Requirement already satisfied: jsonschema in /home/dsc/anaconda3/lib/python3.8/site-packages (from altair) (3.2.0)
# Requirement already satisfied: pandas>=0.18 in /home/dsc/anaconda3/lib/python3.8/site-packages (from altair) (1.1.3)
# Requirement already satisfied: numpy in /home/dsc/anaconda3/lib/python3.8/site-packages (from altair) (1.19.2)
# Requirement already satisfied: toolz in /home/dsc/anaconda3/lib/python3.8/site-packages (from altair) (0.11.1)
# Requirement already satisfied: jinja2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from altair) (2.11.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (0.17.3)
# Requirement already satisfied: setuptools in /home/dsc/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (50.3.1.post20201107)
# Requirement already satisfied: six>=1.11.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (20.3.0)
# Requirement already satisfied: pytz>=2017.2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pandas>=0.18->altair) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/dsc/anaconda3/lib/python3.8/site-packages (from jinja2->altair) (1.1.1)
# Installing collected packages: altair
# Successfully installed altair-4.1.0

# %%
import altair as alt

alt.__version__
# Out:
# '4.1.0'

# %% [markdown]
# ## Example Matplotlib vs Altair

# %%
xs = np.linspace(0,10)
ys = 3 * xs**2

plt.plot(xs, ys)

# %%
alt_df = pd.DataFrame({'X': xs, 'Y': ys})
alt_df.head()
# Out:
#           X         Y
# 0  0.000000  0.000000
# 1  0.204082  0.124948
# 2  0.408163  0.499792
# 3  0.612245  1.124531
# 4  0.816327  1.999167

# %%
alt.Chart(alt_df).mark_line().encode(x='X', y='Y')
# Out:
# alt.Chart(...)

# %% [markdown]
# # Example
#
# Let's build a very simple example with a simple made up dataset

# %%
cars_chart = alt.Chart(cars)

# %%
cars_chart.mark_point()
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_point().encode(x='Miles_per_Gallon')
# Out:
# alt.Chart(...)

# %% [markdown]
# We have just defined the chart but have not tell the chart do anything with the data.
# We have to use the mark attribute of the chart object to specify how we want to visualize it
#
# `alt.Chart(data).mark_*`

# %% [markdown]
# Altair automatically recognizes the data type in the dataframe

# %%
cars_chart.mark_point().encode(x='Miles_per_Gallon',
                              y='Displacement')
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_line().encode(x='Miles_per_Gallon',
                              y='Displacement')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Example taking data from JSON

# %%
data.movies.url
# Out:
# 'https://cdn.jsdelivr.net/npm/vega-datasets@v1.29.0/data/movies.json'

# %%
import requests

# %%
response = requests.get(data.movies.url)
movie_data = response.json()

# %%
movie_chart = alt.Chart(data.movies.url)

movie_chart.mark_point().encode(alt.X('Production_Budget',type='quantitative'), 
                                alt.Y('IMDB_Rating',type='quantitative'))
# Out:
# alt.Chart(...)

# %%
#Esto muestra una barra por cada pelícual, no es un histograma
movie_chart.mark_bar().encode(alt.X('Production_Budget',type='quantitative'), 
                                y='count()')
# Out:
# alt.Chart(...)

# %%
movie_chart.mark_bar().encode(alt.X('Production_Budget',bin=True, type='quantitative'), 
                                y='count()')
# Out:
# alt.Chart(...)

# %%
movie_chart.mark_bar().encode(alt.X('Production_Budget',
                                bin=alt.Bin(extent=[0,3e8],step=1e7), type='quantitative'), 
                                y='count()')
# Out:
# alt.Chart(...)

# %%
movie_chart.mark_bar().encode(alt.X('Production_Budget',
                                bin=alt.Bin(extent=[0,3e8],step=1e7), type='quantitative'), 
                                alt.Y(aggregate='count',type='quantitative'))
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Example 2

# %% [markdown]
# https://altair-viz.github.io/user_guide/generated/toplevel/altair.Chart.html#altair.Chart

# %% [markdown]
# It can be especified using `alt.X`  instead.
#
# The type must also be specified:
# ['quantitative', 'ordinal', 'temporal', 'nominal']

# %% [markdown]
# https://altair-viz.github.io/user_guide/encoding.html#shorthand-description
#
#
# ![shorthand.PNG](data:image/png;base64,...)

# %%
cars_chart.mark_point().encode(x='Origin:N', y='Displacement:Q')
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_bar().encode(x='Origin:N', y='mean(Displacement):Q')
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_bar().encode(x='Origin:N', 
                             y='mean(Displacement):Q',
                            color='Cylinders:Q')
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_bar().encode(x='Origin:N', 
                             y='mean(Displacement):Q',
                            color='Cylinders:N')
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_point().encode(x='Miles_per_Gallon',
                              y='Weight_in_lbs',
                              color='Origin')
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_point().encode(x='Miles_per_Gallon',
                              y='Weight_in_lbs',
                              color='Origin',
                              tooltip='Name').interactive()
# Out:
# alt.Chart(...)

# %%
interval = alt.selection_interval()

cars_chart.mark_point().encode(x='Miles_per_Gallon',
                              y='Weight_in_lbs',
                              color=alt.condition(interval,'Origin',alt.value('lightgrey')),
                              tooltip='Name').add_selection(interval)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Streamlit

# %% [markdown]
# Streamlit is a new library that allow to transform simple python code to web apps easily
#
# https://www.streamlit.io/
#
# https://docs.streamlit.io/en/stable/getting_started.html
#
# https://docs.streamlit.io/en/stable/api.html

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-0.74.1-py2.py3-none-any.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil in /home/dsc/anaconda3/lib/python3.8/site-packages (from streamlit) (2.8.1)
# Collecting protobuf!=3.11,>=3.6.0
#   Downloading protobuf-3.14.0-cp38-cp38-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: click>=7.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from streamlit) (7.1.2)
# Requirement already satisfied: toml in /home/dsc/anaconda3/lib/python3.8/site-packages (from streamlit) (0.10.1)
# Requirement already satisfied: altair>=3.2.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from streamlit) (4.1.0)
# Collecting cachetools>=4.0
#   Downloading cachetools-4.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: requests in /home/dsc/anaconda3/lib/python3.8/site-packages (from streamlit) (2.24.0)
# Collecting gitpython
#   Downloading GitPython-3.1.12-py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 1.8 MB/s eta 0:00:01
# Requirement already satisfied: tornado>=5.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from streamlit) (6.0.4)
# Requirement already satisfied: packaging in /home/dsc/anaconda3/lib/python3.8/site-packages (from streamlit) (20.4)
# Collecting pyarrow; python_version < "3.9"
#   Downloading pyarrow-2.0.0-cp38-cp38-manylinux2014_x86_64.whl (17.8 MB)
#      |████████████████████████████████| 17.8 MB 895 kB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.21.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from streamlit) (1.1.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from streamlit) (8.0.1)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: watchdog; platform_system != "Darwin" in /home/dsc/anaconda3/lib/python3.8/site-packages (from streamlit) (0.10.3)
# Collecting tzlocal
#   Downloading tzlocal-2.1-py2.py3-none-any.whl (16 kB)
# Collecting base58
#   Downloading base58-2.1.0-py3-none-any.whl (5.6 kB)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 3.2 MB/s eta 0:00:01
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: numpy in /home/dsc/anaconda3/lib/python3.8/site-packages (from streamlit) (1.19.2)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.5.0-py2.py3-none-any.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 929 kB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /home/dsc/anaconda3/lib/python3.8/site-packages (from python-dateutil->streamlit) (1.15.0)
# Requirement already satisfied: entrypoints in /home/dsc/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: jinja2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (2.11.2)
# Requirement already satisfied: toolz in /home/dsc/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: jsonschema in /home/dsc/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dsc/anaconda3/lib/python3.8/site-packages (from requests->streamlit) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /home/dsc/anaconda3/lib/python3.8/site-packages (from requests->streamlit) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/dsc/anaconda3/lib/python3.8/site-packages (from requests->streamlit) (1.25.11)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.5-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.2 MB/s eta 0:00:011
# Requirement already satisfied: pyparsing>=2.0.2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: pytz>=2017.2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pandas>=0.21.0->streamlit) (2020.1)
# Requirement already satisfied: pathtools>=0.1.1 in /home/dsc/anaconda3/lib/python3.8/site-packages (from watchdog; platform_system != "Darwin"->streamlit) (0.1.2)
# Requirement already satisfied: decorator>=3.4.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from validators->streamlit) (4.4.2)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in /home/dsc/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (7.5.1)
# Requirement already satisfied: traitlets>=4.3.2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/dsc/anaconda3/lib/python3.8/site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: setuptools in /home/dsc/anaconda3/lib/python3.8/site-packages (from jsonschema->altair>=3.2.0->streamlit) (50.3.1.post20201107)
# Requirement already satisfied: attrs>=17.4.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from jsonschema->altair>=3.2.0->streamlit) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from jsonschema->altair>=3.2.0->streamlit) (0.17.3)
# Collecting smmap<4,>=3.0.1
#   Downloading smmap-3.0.4-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: ipython>=5.0.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (7.19.0)
# Requirement already satisfied: jupyter-client in /home/dsc/anaconda3/lib/python3.8/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (6.1.7)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.0.8)
# Requirement already satisfied: ipython-genutils in /home/dsc/anaconda3/lib/python3.8/site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /home/dsc/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.17.1)
# Requirement already satisfied: backcall in /home/dsc/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /home/dsc/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (3.0.8)
# Requirement already satisfied: pickleshare in /home/dsc/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: pygments in /home/dsc/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (2.7.2)
# Requirement already satisfied: pyzmq>=13 in /home/dsc/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (19.0.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in /home/dsc/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.1.4)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: wcwidth in /home/dsc/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: Send2Trash in /home/dsc/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: prometheus-client in /home/dsc/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.0)
# Requirement already satisfied: argon2-cffi in /home/dsc/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.1.0)
# Requirement already satisfied: nbconvert in /home/dsc/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in /home/dsc/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.1)
# Requirement already satisfied: cffi>=1.0.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.3)
# Requirement already satisfied: defusedxml in /home/dsc/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in /home/dsc/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: testpath in /home/dsc/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/dsc/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: bleach in /home/dsc/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/dsc/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: pycparser in /home/dsc/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Requirement already satisfied: nest-asyncio in /home/dsc/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.2)
# Requirement already satisfied: async-generator in /home/dsc/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.10)
# Requirement already satisfied: webencodings in /home/dsc/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py) ... done
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13452 sha256=7fb3ff1a89c80cf16b35a99889719d6c2c7a5e008583cdb60d16ce2ac7a958be
#   Stored in directory: /home/dsc/.cache/pip/wheels/b7/a5/68/fe632054a5eadd531c7a49d740c50eb6adfbeca822b4eab8d4
# Successfully built blinker
# Installing collected packages: protobuf, cachetools, smmap, gitdb, gitpython, pyarrow, astor, tzlocal, base58, blinker, validators, pydeck, streamlit
# Successfully installed astor-0.8.1 base58-2.1.0 blinker-1.4 cachetools-4.2.0 gitdb-4.0.5 gitpython-3.1.12 protobuf-3.14.0 pyarrow-2.0.0 pydeck-0.5.0 smmap-3.0.4 streamlit-0.74.1 tzlocal-2.1 validators-0.18.2

# %%
import streamlit as st

st.__version__
# Out:
# '0.74.1'

# %%
####soporte@kschool.com

# %% [markdown]
# ### The writefile cell magic
#
# This is a way to keep everything inside the notebook, but it is not the ideal way to code a .py file.

# %%
# %%writefile app.py

hola que tal

mi lista para los reyes es...
# Out:
# Writing app.py

# %%
# %%writefile app.py

print('hello word')
# Out:
# Overwriting app.py

# %%
# %%writefile app.py

import streamlit as st
from vega_datasets import data
import altair as alt

cars = data.cars()

'# Bienvenidos a mi app'

my_chart = alt.Chart(cars).mark_point().encode(x='Displacement',
                                    y='Horsepower')

st.altair_chart(my_chart)
# Out:
# Overwriting app.py

# %%
# streamlit run app.py

# %%
alt.Chart(cars).mark_point().encode(x='Displacement',
                                    y='Horsepower')
# Out:
# alt.Chart(...)

# %%
#discuss.streamlit.io/t/streamlit-on-windows/685

# %% [markdown]
# ### Interacctivity

# %%
# %%writefile app.py

import streamlit as st
from vega_datasets import data
import altair as alt

st.write('# Bienvenidos a mi app')

#Esto se hace por problemas de espacio y lentitud (lee todo el código)


name = st.text_input('¿Como te llamas?')
country = st.selectbox('¿De qué país quieres ver datos?',
              ['USA', 'Europe', 'Japan'])

cars = data.cars()
subset = cars[cars['Origin'] == country]

my_chart = alt.Chart(subset).mark_point().encode(x='Displacement',
                                    y='Horsepower')

st.altair_chart(my_chart)

st.write('gracias por visitar, %s' %name)
# Out:
# Overwriting app.py

# %%
cars['Origin'].unique()
# Out:
# array(['USA', 'Europe', 'Japan'], dtype=object)

# %%
# %%writefile app.py

import streamlit as st
from vega_datasets import data
import altair as alt
import time

st.write('# Bienvenidos a mi app')

#Esto se hace por problemas de espacio y lentitud (lee todo el código)


@st.cache
def get_cars():
    time.sleep(3)
    return data.cars()

@st.cache
def get_subset(origin, df):
    time.sleep(5)
    return df[df['Origin'] == origin]


name = st.text_input('¿Como te llamas?')
country = st.selectbox('¿De qué país quieres ver datos?',
              ['USA', 'Europe', 'Japan'])

cars = get_cars()
subset = get_subset(country, cars)

my_chart = alt.Chart(subset).mark_point().encode(x='Displacement',
                                    y='Horsepower')

st.altair_chart(my_chart)

st.write('gracias por visitar, %s' %name)
# Out:
# Overwriting app.py

# %% [markdown]
# # Bokeh
#
# Bokeh "is a Python interactive visualization library that targets
# modern web browsers for presentation".
#
# Two components: A Python backend and a JS frontend.
#
# The way we use it is to declare our graphs in Python.
#
# The Python objects will in turn generate a series of JSON objects that describe a _scenegraph_. The JS component will generate the actual visualization from that scenegraph. The upside of this is that we don't need to work with JS, but our visualizations will be browser-based and interactive
#
# https://bokeh.pydata.org/en/latest/docs/gallery.html
#
# https://bokeh.pydata.org/en/latest/

# %% [markdown]
# # Plotly
#
# https://www.analyticsvidhya.com/blog/2017/01/beginners-guide-to-create-beautiful-interactive-data-visualizations-using-plotly-in-r-and-python/
#
# Plotly is a multi-language tool for creating interactive visualizations. It's built on top  of D3.

# %% [markdown]
# ## Dash
#
# "Shiny for Python"

# %% [markdown]
# # Additional references
#
# [Matplotlib documentation](http://matplotlib.org/contents.html)
#
# [The matplotlib FAQ](http://matplotlib.org/faq/usage_faq.html)
#
# [Matplotlib cheat sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf)
#
# [Nicolas P. Rougier's matplotlib tutorial](http://www.labri.fr/perso/nrougier/teaching/matplotlib/)
#
# [Anatomy of Matplotlib](https://github.com/matplotlib/AnatomyOfMatplotlib)
#
# [$\LaTeX$](https://www.latex-project.org/)
#
# [Python graph gallery](https://python-graph-gallery.com/)
#
# [Effective matplotlib](https://pbpython.com/effective-matplotlib.html)
#
# [Python Data Science Handbook](https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/Index.ipynb)
#
# [more plots](https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/)
#
# https://www.datacamp.com/community/tutorials/seaborn-python-tutorial
#
#
# [Bokeh User Guide](http://bokeh.pydata.org/en/latest/docs/user_guide.html)
#
# [Bokeh Tutorials](http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/index.ipynb)
#
# [Dash](https://plot.ly/dash/)
#
# [Dash being spotted before release](https://www.reddit.com/r/Python/comments/6imhxa/plotly_has_just_released_dash_20_a_shinylike_tool/)
#
# [Facets](https://pair-code.github.io/facets/)
#
# [Facets release Google research blog entry](https://research.googleblog.com/2017/07/facets-open-source-visualization-tool.html)
#
# [A great Altair tutorial](https://github.com/altair-viz/altair-tutorial)
